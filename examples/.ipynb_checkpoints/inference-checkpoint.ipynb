# %%
# %load_ext autoreload
# %autoreload 2

import os
os.chdir(os.path.abspath(".."))

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Setup
# First of all, check the Python version. This sources have been coded with the following Python version:

# %%
# !python --version
# Out:
# Python 3.11.2

# %% [markdown]
# Then, install the dependencies in the `requirement.txt` file. The main dependency is the python packege `bcause` (https://github.com/PGM-Lab/bcause).

# %%
# !pip install --upgrade pip setuptools wheel
# !pip install -r ./requirements.txt

# %% [markdown]
# ## Model and data
#
# In this repository, we provide functionality for preprocessing the model and data so they could work we our inference algorithm:

# %%
from ctfzeros.prepro import load_and_preprocess

# %%
filepath = "./models/synthetic/simple_nparents2_nzr04_zdr05_10.uai"
datapath = "./models/synthetic/simple_nparents2_nzr04_zdr05_10.csv"

model, data, _, _ = load_and_preprocess(filepath, datapath)
model
# Out:
# <StructuralCausalModel (Y:2,X2:2,X1:2|Uy:14,Ux1:2,Ux2:2), dag=[Uy][Y|Uy:X2:X1][X2|Ux2][X1|Ux1][Ux1][Ux2]>

# %%
model.draw()

# %%
data
# Out:
#      X2  X1  Y
# 0     0   1  1
# 1     0   0  1
# 2     0   0  1
# 3     0   0  1
# 4     0   0  1
# ..   ..  .. ..
# 995   0   1  1
# 996   0   0  1
# 997   1   0  1
# 998   0   0  0
# 999   0   0  1
#
# [1000 rows x 3 columns]

# %% [markdown]
# ## Counterfactual inference
#
# First, load corresponding modules for using DCCC and EMCC:

# %%
from ctfzeros.divideconquer import DCCC_inverted_tree
from bcause.inference.causal.multi import EMCC

# %% [markdown]
# Set up the DCCC inference engine with a number of solutions $N=20$. Then calculate the probability of sufficiency $PS(X_2,Y)$:

# %%
import ctfzeros.divideconquer
ctfzeros.divideconquer.__file__
# Out:
# '/Users/rcabanas/GoogleDrive/UAL/research/causality/dev/repo/2025-IJAR-DCCC/ctfzeros/divideconquer.py'

# %%
infDCCC = DCCC_inverted_tree(model, data, num_runs=20)

for _ in infDCCC.compile_incremental(step_runs=1):
   p = infDCCC.prob_sufficiency("X2","Y")
   print(p)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 3
#       1 infDCCC = DCCC_inverted_tree(model, data, num_runs=20)
# ----> 3 for _ in infDCCC.compile_incremental(step_runs=1):
#       4    p = infDCCC.prob_sufficiency("X2","Y")
#       5    print(p)
#
# File ~/GoogleDrive/UAL/research/causality/dev/repo/2025-IJAR-DCCC/ctfzeros/divideconquer.py:116, in DCCC_inverted_tree.compile_incremental(self, step_runs, *args, **kwargs)
#     114      self.add_models(models)
#     115      models = []
# --> 116      yield super().compile()
#     118 else:
#     119
#     120  #def compile_incremental_old(self, step_runs=1, *args, **kwargs) -> Inference:
#     121      models = []
#
# File ~/MCD/2025-IJAR-DCCC311/lib/python3.11/site-packages/bcause/inference/causal/multi.py:54, in CausalMultiInference.compile(self, *args, **kwargs)
#      53 def compile(self, *args, **kwargs) -> Inference:
# ---> 54     if len(self._models)<1: raise ValueError("Required at least 1 precise model")
#      55     t1 = Watch.time_absolut()
#      57     self._model = self._models[0]
#
# ValueError: Required at least 1 precise model

# %%
infDCCC = DCCC_inverted_tree(model, data, num_runs=20)
infDCCC.prob_sufficiency("X2","Y")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 2
#       1 infDCCC = DCCC_inverted_tree(model, data, num_runs=20)
# ----> 2 infDCCC.prob_sufficiency("X2","Y")
#
# File ~/MCD/2025-IJAR-DCCC311/lib/python3.11/site-packages/bcause/inference/causal/multi.py:143, in CausalMultiInference.prob_sufficiency(self, cause, effect, true_false_cause, true_false_effect)
#     141 interval_result = self._interval_result
#     142 self._interval_result = False
# --> 143 result = self.counterfactual_query(
#     144     effect,
#     145     do={cause: Tcause},
#     146     evidence={cause: Fcause, effect: Feffect}
#     147 )
#     148 self._interval_result = interval_result
#     150 return self._process_output(result, {effect+"_1": Teffect})
#
# File ~/MCD/2025-IJAR-DCCC311/lib/python3.11/site-packages/bcause/inference/causal/causal.py:88, in CausalInference.counterfactual_query(self, target, do, evidence, targets_subgraphs)
#      87 def counterfactual_query(self, target, do, evidence=None, targets_subgraphs = None):
# ---> 88     return self.query(target, do, evidence=evidence, counterfactual=True, targets_subgraphs=targets_subgraphs)
#
# File ~/MCD/2025-IJAR-DCCC311/lib/python3.11/site-packages/bcause/inference/causal/multi.py:75, in CausalMultiInference.query(self, target, do, evidence, counterfactual, targets_subgraphs)
#      72 def query(self, target, do=None, evidence=None, counterfactual=False, targets_subgraphs = None):
#      73     do = do or dict()
# ---> 75     if not self._compiled: self.compile()
#      76     results = [inf.query(target, do, evidence, counterfactual, targets_subgraphs)  for inf in self._causal_inf]
#      77     if len(results)==0:
#
# File ~/GoogleDrive/UAL/research/causality/dev/repo/2025-IJAR-DCCC/ctfzeros/divideconquer.py:79, in DCCC_inverted_tree.compile(self, *args, **kwargs)
#      77         models.append(update_exo_probs(self._prior_model, self.new_doms, self.new_probs))
#      78     self.add_models(models)
# ---> 79     return super().compile()
#      82 else:
#      83     models = []
#
# File ~/MCD/2025-IJAR-DCCC311/lib/python3.11/site-packages/bcause/inference/causal/multi.py:54, in CausalMultiInference.compile(self, *args, **kwargs)
#      53 def compile(self, *args, **kwargs) -> Inference:
# ---> 54     if len(self._models)<1: raise ValueError("Required at least 1 precise model")
#      55     t1 = Watch.time_absolut()
#      57     self._model = self._models[0]
#
# ValueError: Required at least 1 precise model

# %% [markdown]
# Similarly, with the state of the art method EMCC interating up to 100 iterations each EM run.

# %%
infEMCC = EMCC(model,data,num_runs=20, max_iter=100)
infEMCC.prob_sufficiency("X2","Y")
# Out:
# [0.8872483149711372, 0.9970894129396131]
